# %%
import pandas as pd

# %%
data_2023 = pd.read_csv("data_all_years/202306-citibike-tripdata.csv", encoding='UTF-8')

# %%
data_2023.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  37BE5FCB1A385CDA   classic_bike  2023-06-27 16:06:27  2023-06-27 16:10:27
# 1  9C96B4C6CBBB31AD   classic_bike  2023-06-24 10:46:58  2023-06-24 10:55:27
# 2  C91293605D4BEC07  electric_bike  2023-06-04 20:30:13  2023-06-04 20:34:31
# 3  2920063442116A46   classic_bike  2023-06-08 19:10:06  2023-06-08 19:13:05
# 4  E205FD8C18BA263A   classic_bike  2023-06-23 18:53:51  2023-06-23 19:17:50
#
#       start_station_name start_station_id  end_station_name end_station_id  \
# 0                Hilltop            JC019   Christ Hospital          JC034
# 1  Baldwin at Montgomery            JC020     Hamilton Park          JC009
# 2                Hilltop            JC019      Brunswick St          JC023
# 3  Baldwin at Montgomery            JC020       Astor Place          JC077
# 4  Baldwin at Montgomery            JC020  Adams St & 11 St          HB507
#
# ...

# %%
data_2023.columns.to_list()
# Out:
# ['ride_id',
#  'rideable_type',
#  'started_at',
#  'ended_at',
#  'start_station_name',
#  'start_station_id',
#  'end_station_name',
#  'end_station_id',
#  'start_lat',
#  'start_lng',
#  'end_lat',
#  'end_lng',
#  'member_casual']

# %%
data_2023_clean = data_2023.drop(columns=["rideable_type", "ride_id"])
data_2023_clean.head()
# Out:
#             started_at             ended_at     start_station_name  \
# 0  2023-06-27 16:06:27  2023-06-27 16:10:27                Hilltop
# 1  2023-06-24 10:46:58  2023-06-24 10:55:27  Baldwin at Montgomery
# 2  2023-06-04 20:30:13  2023-06-04 20:34:31                Hilltop
# 3  2023-06-08 19:10:06  2023-06-08 19:13:05  Baldwin at Montgomery
# 4  2023-06-23 18:53:51  2023-06-23 19:17:50  Baldwin at Montgomery
#
#   start_station_id  end_station_name end_station_id  start_lat  start_lng  \
# 0            JC019   Christ Hospital          JC034  40.731115 -74.057468
# 1            JC020     Hamilton Park          JC009  40.723473 -74.064338
# 2            JC019      Brunswick St          JC023  40.731169 -74.057574
# 3            JC020       Astor Place          JC077  40.723499 -74.064335
# 4            JC020  Adams St & 11 St          HB507  40.723511 -74.064277
#
#      end_lat    end_lng member_casual
# 0  40.734786 -74.050444        casual
# 1  40.727596 -74.044247        member
# ...

# %%
data_2022 = pd.read_csv("data_all_years/202206-citibike-tripdata.csv", encoding='UTF-8')

# %%
data_2022.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  EEA3CD3B084370F4   classic_bike  2022-06-30 19:17:16  2022-06-30 19:27:13
# 1  BF568C9B3C5FAE94   classic_bike  2022-06-02 12:46:44  2022-06-02 15:08:33
# 2  DF6B06D460481A7E   classic_bike  2022-06-05 14:17:34  2022-06-05 14:27:12
# 3  A26CDB92CDF7E0EE  electric_bike  2022-06-01 18:57:12  2022-06-01 19:05:58
# 4  A2A50E81031E9E7F  electric_bike  2022-06-14 22:45:53  2022-06-14 22:49:39
#
#        start_station_name start_station_id  end_station_name end_station_id  \
# 0  Clinton St & Newark St            HB409  Grand St & 14 St          HB506
# 1  Clinton St & Newark St            HB409  Grand St & 14 St          HB506
# 2  Clinton St & Newark St            HB409  Grand St & 14 St          HB506
# 3  Clinton St & Newark St            HB409    Pershing Field          JC024
# 4             Oakland Ave            JC022    Pershing Field          JC024
#
# ...

# %%
data_2022.columns.to_list()
# Out:
# ['ride_id',
#  'rideable_type',
#  'started_at',
#  'ended_at',
#  'start_station_name',
#  'start_station_id',
#  'end_station_name',
#  'end_station_id',
#  'start_lat',
#  'start_lng',
#  'end_lat',
#  'end_lng',
#  'member_casual']

# %%
data_2022_clean = data_2022.drop(columns=["rideable_type", "ride_id"])

# %%
data_2021 = pd.read_csv("data_all_years/202106-citibike-tripdata.csv", encoding='UTF-8')

# %%
data_2021.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  7830EBE775F2EE25  classic_bike  2021-06-21 07:38:42  2021-06-21 10:49:25
# 1  629A3BFD50BF8392   docked_bike  2021-06-12 10:25:01  2021-06-12 10:35:11
# 2  CF02EC434989A99D   docked_bike  2021-06-07 14:52:05  2021-06-07 14:58:25
# 3  E1BB8FED29AA5BA1   docked_bike  2021-06-07 08:29:19  2021-06-07 08:34:17
# 4  787C59EE76D96BCA   docked_bike  2021-06-18 14:16:27  2021-06-18 14:26:26
#
#       start_station_name start_station_id  \
# 0            Dixon Mills            JC076
# 1            Dixon Mills            JC076
# 2  11 St & Washington St            HB502
# 3   8 St & Washington St            HB603
# 4  11 St & Washington St            HB502
#
#                            end_station_name end_station_id  start_lat  \
# 0                                       NaN            NaN  40.721630
# 1                            Journal Square          JC103  40.721630
# ...

# %%
data_2021.columns.to_list()
# Out:
# ['ride_id',
#  'rideable_type',
#  'started_at',
#  'ended_at',
#  'start_station_name',
#  'start_station_id',
#  'end_station_name',
#  'end_station_id',
#  'start_lat',
#  'start_lng',
#  'end_lat',
#  'end_lng',
#  'member_casual']

# %%
data_2021_clean = data_2021.drop(columns=["rideable_type", "ride_id"])
data_2021_clean.head()
# Out:
#             started_at             ended_at     start_station_name  \
# 0  2021-06-21 07:38:42  2021-06-21 10:49:25            Dixon Mills
# 1  2021-06-12 10:25:01  2021-06-12 10:35:11            Dixon Mills
# 2  2021-06-07 14:52:05  2021-06-07 14:58:25  11 St & Washington St
# 3  2021-06-07 08:29:19  2021-06-07 08:34:17   8 St & Washington St
# 4  2021-06-18 14:16:27  2021-06-18 14:26:26  11 St & Washington St
#
#   start_station_id                          end_station_name end_station_id  \
# 0            JC076                                       NaN            NaN
# 1            JC076                            Journal Square          JC103
# 2            HB502  Hoboken Terminal - Hudson St & Hudson Pl          HB101
# 3            HB603  Hoboken Terminal - Hudson St & Hudson Pl          HB101
# 4            HB502         Columbus Park - Clinton St & 9 St          HB501
#
#    start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %%
data_2020 = pd.read_csv("data_all_years/202006-citibike-tripdata.csv", encoding='UTF-8')

# %%
data_2020.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           122  2020-06-01 00:02:21.7500  2020-06-01 00:04:24.3250
# 1          1282  2020-06-01 00:12:27.1090  2020-06-01 00:33:50.0540
# 2           186  2020-06-01 01:19:59.2090  2020-06-01 01:23:05.8930
# 3           131  2020-06-01 01:26:42.2050  2020-06-01 01:28:53.8040
# 4           266  2020-06-01 01:27:33.7090  2020-06-01 01:32:00.1890
#
#    start station id          start station name  start station latitude  \
# 0              3792  Columbus Dr at Exchange Pl               40.716870
# 1              3198            Heights Elevator               40.748716
# 2              3275              Columbus Drive               40.718355
# 3              3267                Morris Canal               40.712419
# 4              3639                  Harborside               40.719252
#
#    start station longitude  end station id  end station name  \
# ...

# %%
data_2020.columns.to_list()
# Out:
# ['tripduration',
#  'starttime',
#  'stoptime',
#  'start station id',
#  'start station name',
#  'start station latitude',
#  'start station longitude',
#  'end station id',
#  'end station name',
#  'end station latitude',
#  'end station longitude',
#  'bikeid',
#  'usertype',
#  'birth year',
#  'gender']

# %%
data_2020_clean = data_2020[["starttime", "stoptime", "start station id", "start station name",
                           "start station latitude", "start station longitude", "end station id",
                           "end station name", "end station latitude", "end station longitude",
                           "usertype"]]
data_2020_clean.head()
# Out:
#                   starttime                  stoptime  start station id  \
# 0  2020-06-01 00:02:21.7500  2020-06-01 00:04:24.3250              3792
# 1  2020-06-01 00:12:27.1090  2020-06-01 00:33:50.0540              3198
# 2  2020-06-01 01:19:59.2090  2020-06-01 01:23:05.8930              3275
# 3  2020-06-01 01:26:42.2050  2020-06-01 01:28:53.8040              3267
# 4  2020-06-01 01:27:33.7090  2020-06-01 01:32:00.1890              3639
#
#            start station name  start station latitude  \
# 0  Columbus Dr at Exchange Pl               40.716870
# 1            Heights Elevator               40.748716
# 2              Columbus Drive               40.718355
# 3                Morris Canal               40.712419
# 4                  Harborside               40.719252
#
#    start station longitude  end station id  end station name  \
# 0               -74.032810            3639        Harborside
# 1               -74.040443            3276  Marin Light Rail
# ...

# %%
data_2020_renamed = data_2020_clean.rename(columns={"starttime": "started_at", "stoptime": "ended_at", "start station id": "start_station_id",
                               "start station name": "start_station_name", "start station latitude": "start_lat",
                               "start station longitude": "start_lng", "end station id": "end_station_id",
                               "end station name": "end_station_name", "end station latitude": "end_lat",
                               "end station longitude": "end_lng", "usertype": "member_casual"})

# %%
data_2020_arranged = data_2020_renamed[["started_at", "ended_at", "start_station_name", "start_station_id", "end_station_name",
                "end_station_id", "start_lat", "start_lng", "end_lat", "end_lng", "member_casual"]]

data_2020_arranged.head()
# Out:
#                  started_at                  ended_at  \
# 0  2020-06-01 00:02:21.7500  2020-06-01 00:04:24.3250
# 1  2020-06-01 00:12:27.1090  2020-06-01 00:33:50.0540
# 2  2020-06-01 01:19:59.2090  2020-06-01 01:23:05.8930
# 3  2020-06-01 01:26:42.2050  2020-06-01 01:28:53.8040
# 4  2020-06-01 01:27:33.7090  2020-06-01 01:32:00.1890
#
#            start_station_name  start_station_id  end_station_name  \
# 0  Columbus Dr at Exchange Pl              3792        Harborside
# 1            Heights Elevator              3198  Marin Light Rail
# 2              Columbus Drive              3275          Grand St
# 3                Morris Canal              3267          Grand St
# 4                  Harborside              3639     Grove St PATH
#
#    end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# 0            3639  40.716870 -74.032810  40.719252 -74.034234    Subscriber
# 1            3276  40.748716 -74.040443  40.714584 -74.042817    Subscriber
# ...

# %%
data_2020_arranged["member_casual"] = data_2020_arranged["member_casual"].replace(["Subscriber"], "member")

# %%
data_2020_arranged["member_casual"] = data_2020_arranged["member_casual"].replace(["Customer"], "casual")

# %%
data_2020_arranged.head()
# Out:
#                  started_at                  ended_at  \
# 0  2020-06-01 00:02:21.7500  2020-06-01 00:04:24.3250
# 1  2020-06-01 00:12:27.1090  2020-06-01 00:33:50.0540
# 2  2020-06-01 01:19:59.2090  2020-06-01 01:23:05.8930
# 3  2020-06-01 01:26:42.2050  2020-06-01 01:28:53.8040
# 4  2020-06-01 01:27:33.7090  2020-06-01 01:32:00.1890
#
#            start_station_name  start_station_id  end_station_name  \
# 0  Columbus Dr at Exchange Pl              3792        Harborside
# 1            Heights Elevator              3198  Marin Light Rail
# 2              Columbus Drive              3275          Grand St
# 3                Morris Canal              3267          Grand St
# 4                  Harborside              3639     Grove St PATH
#
#    end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# 0            3639  40.716870 -74.032810  40.719252 -74.034234        member
# 1            3276  40.748716 -74.040443  40.714584 -74.042817        member
# ...

# %%
data_2019 = pd.read_csv("data_all_years/201906-citibike-tripdata.csv", encoding='UTF-8')

# %%
data_2019_clean = data_2019[["starttime", "stoptime", "start station id", "start station name",
                           "start station latitude", "start station longitude", "end station id",
                           "end station name", "end station latitude", "end station longitude",
                           "usertype"]]
data_2019_clean.head()
# Out:
#                   starttime                  stoptime  start station id  \
# 0  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940              3187
# 1  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730              3185
# 2  2019-06-01 00:13:11.8800  2019-06-01 00:49:14.3640              3199
# 3  2019-06-01 00:13:30.1110  2019-06-01 00:49:54.2250              3199
# 4  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880              3207
#
#   start station name  start station latitude  start station longitude  \
# 0          Warren St               40.721124               -74.038051
# 1          City Hall               40.717732               -74.043845
# 2       Newport Pkwy               40.728745               -74.032108
# 3       Newport Pkwy               40.728745               -74.032108
# 4        Oakland Ave               40.737604               -74.052478
#
#    end station id end station name  end station latitude  \
# ...

# %%
data_2019_renamed = data_2019_clean.rename(columns={"starttime": "started_at", "stoptime": "ended_at", "start station id": "start_station_id",
                               "start station name": "start_station_name", "start station latitude": "start_lat",
                               "start station longitude": "start_lng", "end station id": "end_station_id",
                               "end station name": "end_station_name", "end station latitude": "end_lat",
                               "end station longitude": "end_lng", "usertype": "member_casual"})

# %%
data_2019_arranged = data_2019_renamed[["started_at", "ended_at", "start_station_name", "start_station_id", "end_station_name",
                "end_station_id", "start_lat", "start_lng", "end_lat", "end_lng", "member_casual"]]

# %%
data_2019_arranged["member_casual"] = data_2019_arranged["member_casual"].replace(["Subscriber"], "member")
data_2019_arranged["member_casual"] = data_2019_arranged["member_casual"].replace(["Customer"], "casual")

# %%
data_2019_arranged.head()
# Out:
#                  started_at                  ended_at start_station_name  \
# 0  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940          Warren St
# 1  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730          City Hall
# 2  2019-06-01 00:13:11.8800  2019-06-01 00:49:14.3640       Newport Pkwy
# 3  2019-06-01 00:13:30.1110  2019-06-01 00:49:54.2250       Newport Pkwy
# 4  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880        Oakland Ave
#
#    start_station_id end_station_name  end_station_id  start_lat  start_lng  \
# 0              3187     Newport Pkwy            3199  40.721124 -74.038051
# 1              3185     Morris Canal            3267  40.717732 -74.043845
# 2              3199     Newport Pkwy            3199  40.728745 -74.032108
# 3              3199     Newport Pkwy            3199  40.728745 -74.032108
# 4              3207      Oakland Ave            3207  40.737604 -74.052478
#
#      end_lat    end_lng member_casual
# ...

# %%
data_2018 = pd.read_csv("data_all_years/201806-citibike-tripdata.csv", encoding='UTF-8')

# %%
data_2018_clean = data_2018[["starttime", "stoptime", "start station id", "start station name",
                           "start station latitude", "start station longitude", "end station id",
                           "end station name", "end station latitude", "end station longitude",
                           "usertype"]]

# %%
data_2018_renamed = data_2018_clean.rename(columns={"starttime": "started_at", "stoptime": "ended_at", "start station id": "start_station_id",
                               "start station name": "start_station_name", "start station latitude": "start_lat",
                               "start station longitude": "start_lng", "end station id": "end_station_id",
                               "end station name": "end_station_name", "end station latitude": "end_lat",
                               "end station longitude": "end_lng", "usertype": "member_casual"})

# %%
data_2018_arranged = data_2018_renamed[["started_at", "ended_at", "start_station_name", "start_station_id", "end_station_name",
                "end_station_id", "start_lat", "start_lng", "end_lat", "end_lng", "member_casual"]]

# %%
data_2018_arranged["member_casual"] = data_2018_arranged["member_casual"].replace(["Subscriber"], "member")
data_2018_arranged["member_casual"] = data_2018_arranged["member_casual"].replace(["Customer"], "casual")

# %%
data_2018_arranged.head()
# Out:
#                  started_at                  ended_at start_station_name  \
# 0  2018-06-01 07:07:00.2990  2018-06-01 07:12:30.2220     Exchange Place
# 1  2018-06-01 08:24:43.8490  2018-06-01 08:29:03.8450     Exchange Place
# 2  2018-06-01 09:17:49.5730  2018-06-01 09:29:16.1770     Exchange Place
# 3  2018-06-01 09:44:00.4020  2018-06-01 09:46:44.6830     Exchange Place
# 4  2018-06-01 09:59:28.7800  2018-06-01 10:12:18.6660     Exchange Place
#
#    start_station_id  end_station_name  end_station_id  start_lat  start_lng  \
# 0              3183  Marin Light Rail            3276  40.716247 -74.033459
# 1              3183      Morris Canal            3267  40.716247 -74.033459
# 2              3183      Newport PATH            3202  40.716247 -74.033459
# 3              3183      Morris Canal            3267  40.716247 -74.033459
# 4              3183     Hamilton Park            3203  40.716247 -74.033459
#
#      end_lat    end_lng member_casual
# ...

# %%
data_2017 = pd.read_csv("data_all_years/201706-citibike-tripdata.csv", encoding='UTF-8')

# %%
data_2017_clean = data_2017[["starttime", "stoptime", "start station id", "start station name",
                           "start station latitude", "start station longitude", "end station id",
                           "end station name", "end station latitude", "end station longitude",
                           "usertype"]]

# %%
data_2017_renamed = data_2017_clean.rename(columns={"starttime": "started_at", "stoptime": "ended_at", "start station id": "start_station_id",
                               "start station name": "start_station_name", "start station latitude": "start_lat",
                               "start station longitude": "start_lng", "end station id": "end_station_id",
                               "end station name": "end_station_name", "end station latitude": "end_lat",
                               "end station longitude": "end_lng", "usertype": "member_casual"})

# %%
data_2017_arranged = data_2017_renamed[["started_at", "ended_at", "start_station_name", "start_station_id", "end_station_name",
                "end_station_id", "start_lat", "start_lng", "end_lat", "end_lng", "member_casual"]]

# %%
data_2017_arranged["member_casual"] = data_2017_arranged["member_casual"].replace(["Subscriber"], "member")
data_2017_arranged["member_casual"] = data_2017_arranged["member_casual"].replace(["Customer"], "casual")

# %%
data_2017_arranged.head()
# Out:
#             started_at             ended_at start_station_name  \
# 0  2017-06-01 00:01:39  2017-06-01 00:09:59            Sip Ave
# 1  2017-06-01 00:06:39  2017-06-01 00:15:07         Newark Ave
# 2  2017-06-01 00:44:43  2017-06-01 00:57:31            Sip Ave
# 3  2017-06-01 01:12:55  2017-06-01 01:14:36          City Hall
# 4  2017-06-01 01:14:00  2017-06-01 01:18:25       Manila & 1st
#
#    start_station_id         end_station_name  end_station_id  start_lat  \
# 0              3195          McGinley Square            3194  40.730743
# 1              3211  Communipaw & Berry Lane            3277  40.721525
# 2              3195     West Side Light Rail            3189  40.730743
# 3              3185           Van Vorst Park            3213  40.717732
# 4              3273         Monmouth and 6th            3278  40.721651
#
#    start_lng    end_lat    end_lng member_casual
# 0 -74.063784  40.725340 -74.067622        member
# 1 -74.046305  40.714358 -74.066611        member
# ...

# %%
data_2016 = pd.read_csv("data_all_years/201606-citibike-tripdata.csv", encoding='UTF-8')
data_2016.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            669  2016-06-01 00:00:37  2016-06-01 00:11:46              3186
# 1            945  2016-06-01 00:14:54  2016-06-01 00:30:40              3199
# 2            334  2016-06-01 00:34:52  2016-06-01 00:40:26              3186
# 3            473  2016-06-01 00:40:30  2016-06-01 00:48:23              3185
# 4            551  2016-06-01 00:50:06  2016-06-01 00:59:17              3220
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0      Grove St PATH               40.719586               -74.043117
# 1       Newport Pkwy               40.728745               -74.032108
# 2      Grove St PATH               40.719586               -74.043117
# 3          City Hall               40.717732               -74.043845
# 4  5 Corners Library               40.734961               -74.059503
#
#    End Station ID      End Station Name  End Station Latitude  \
# ...

# %%
data_2016_clean = data_2016[["Start Time", "Stop Time", "Start Station ID", "Start Station Name",
                           "Start Station Latitude", "Start Station Longitude", "End Station ID",
                           "End Station Name", "End Station Latitude", "End Station Longitude",
                           "User Type"]]

# %%
data_2016_renamed = data_2016_clean.rename(columns={"Start Time": "started_at", "Stop Time": "ended_at", "Start Station ID": "start_station_id",
                               "Start Station Name": "start_station_name", "Start Station Latitude": "start_lat",
                               "Start Station Longitude": "start_lng", "End Station ID": "end_station_id",
                               "End Station Name": "end_station_name", "End Station Latitude": "end_lat",
                               "End Station Longitude": "end_lng", "User Type": "member_casual"})

# %%
data_2016_arranged = data_2016_renamed[["started_at", "ended_at", "start_station_name", "start_station_id", "end_station_name",
                "end_station_id", "start_lat", "start_lng", "end_lat", "end_lng", "member_casual"]]

# %%
data_2016_arranged["member_casual"] = data_2016_arranged["member_casual"].replace(["Subscriber"], "member")
data_2016_arranged["member_casual"] = data_2016_arranged["member_casual"].replace(["Customer"], "casual")

# %%
data_2016_arranged.head()
# Out:
#             started_at             ended_at start_station_name  \
# 0  2016-06-01 00:00:37  2016-06-01 00:11:46      Grove St PATH
# 1  2016-06-01 00:14:54  2016-06-01 00:30:40       Newport Pkwy
# 2  2016-06-01 00:34:52  2016-06-01 00:40:26      Grove St PATH
# 3  2016-06-01 00:40:30  2016-06-01 00:48:23          City Hall
# 4  2016-06-01 00:50:06  2016-06-01 00:59:17  5 Corners Library
#
#    start_station_id      end_station_name  end_station_id  start_lat  \
# 0              3186  Garfield Ave Station            3190  40.719586
# 1              3199          Newport Pkwy            3199  40.728745
# 2              3186          Brunswick St            3209  40.719586
# 3              3185    Liberty Light Rail            3192  40.717732
# 4              3220              North St            3197  40.734961
#
#    start_lng    end_lat    end_lng member_casual
# 0 -74.043117  40.710467 -74.070039        member
# 1 -74.032108  40.728745 -74.032108        member
# ...

# %%
data_2015 = pd.read_csv("data_all_years/201506-citibike-tripdata.csv", encoding='UTF-8')
data_2015.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0          1338  6/1/2015 0:00  6/1/2015 0:22               128
# 1           290  6/1/2015 0:00  6/1/2015 0:05               438
# 2           634  6/1/2015 0:01  6/1/2015 0:11               383
# 3           159  6/1/2015 0:01  6/1/2015 0:04               361
# 4          1233  6/1/2015 0:02  6/1/2015 0:22               382
#
#            start station name  start station latitude  \
# 0    MacDougal St & Prince St               40.727103
# 1         St Marks Pl & 1 Ave               40.727791
# 2  Greenwich Ave & Charles St               40.735238
# 3        Allen St & Hester St               40.716059
# 4     University Pl & E 14 St               40.734927
#
#    start station longitude  end station id         end station name  \
# 0               -74.002971            2021          W 45 St & 8 Ave
# 1               -73.985649             312  Allen St & E Houston St
# ...

# %%
data_2015_clean = data_2015[["starttime", "stoptime", "start station id", "start station name",
                           "start station latitude", "start station longitude", "end station id",
                           "end station name", "end station latitude", "end station longitude",
                           "usertype"]]

# %%
data_2015_renamed = data_2015_clean.rename(columns={"starttime": "started_at", "stoptime": "ended_at", "start station id": "start_station_id",
                               "start station name": "start_station_name", "start station latitude": "start_lat",
                               "start station longitude": "start_lng", "end station id": "end_station_id",
                               "end station name": "end_station_name", "end station latitude": "end_lat",
                               "end station longitude": "end_lng", "usertype": "member_casual"})

# %%
data_2015_arranged = data_2015_renamed[["started_at", "ended_at", "start_station_name", "start_station_id", "end_station_name",
                "end_station_id", "start_lat", "start_lng", "end_lat", "end_lng", "member_casual"]]

# %%
data_2015_arranged["member_casual"] = data_2015_arranged["member_casual"].replace(["Subscriber"], "member")
data_2015_arranged["member_casual"] = data_2015_arranged["member_casual"].replace(["Customer"], "casual")

# %%
data_2015_arranged.head()
# Out:
#       started_at       ended_at          start_station_name  start_station_id  \
# 0  6/1/2015 0:00  6/1/2015 0:22    MacDougal St & Prince St               128
# 1  6/1/2015 0:00  6/1/2015 0:05         St Marks Pl & 1 Ave               438
# 2  6/1/2015 0:01  6/1/2015 0:11  Greenwich Ave & Charles St               383
# 3  6/1/2015 0:01  6/1/2015 0:04        Allen St & Hester St               361
# 4  6/1/2015 0:02  6/1/2015 0:22     University Pl & E 14 St               382
#
#           end_station_name  end_station_id  start_lat  start_lng    end_lat  \
# 0          W 45 St & 8 Ave            2021  40.727103 -74.002971  40.759291
# 1  Allen St & E Houston St             312  40.727791 -73.985649  40.722055
# 2         W 26 St & 10 Ave             388  40.735238 -74.000271  40.749718
# 3   Forsyth St & Broome St             531  40.716059 -73.991908  40.718939
# 4          S 5 Pl & S 4 St             532  40.734927 -73.992005  40.710451
#
#      end_lng member_casual
# ...

# %%
data_2014 = pd.read_csv("data_all_years/201406-citibike-tripdata.csv", encoding='UTF-8')
data_2014.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           520  2014-06-01 00:00:02  2014-06-01 00:08:42               358
# 1           520  2014-06-01 00:00:27  2014-06-01 00:09:07               335
# 2           414  2014-06-01 00:00:32  2014-06-01 00:07:26               439
# 3           310  2014-06-01 00:00:34  2014-06-01 00:05:44               463
# 4           457  2014-06-01 00:00:35  2014-06-01 00:08:12               352
#
#               start station name  start station latitude  \
# 0  Christopher St & Greenwich St               40.732916
# 1       Washington Pl & Broadway               40.729039
# 2                 E 4 St & 2 Ave               40.726281
# 3                9 Ave & W 16 St               40.742065
# 4                W 56 St & 6 Ave               40.763406
#
#    start station longitude  end station id          end station name  \
# 0               -74.007114             426     West St & Chambers St
# ...

# %%
data_2014_clean = data_2014[["starttime", "stoptime", "start station id", "start station name",
                           "start station latitude", "start station longitude", "end station id",
                           "end station name", "end station latitude", "end station longitude",
                           "usertype"]]

# %%
data_2014_renamed = data_2014_clean.rename(columns={"starttime": "started_at", "stoptime": "ended_at", "start station id": "start_station_id",
                               "start station name": "start_station_name", "start station latitude": "start_lat",
                               "start station longitude": "start_lng", "end station id": "end_station_id",
                               "end station name": "end_station_name", "end station latitude": "end_lat",
                               "end station longitude": "end_lng", "usertype": "member_casual"})

# %%
data_2014_arranged = data_2014_renamed[["started_at", "ended_at", "start_station_name", "start_station_id", "end_station_name",
                "end_station_id", "start_lat", "start_lng", "end_lat", "end_lng", "member_casual"]]

# %%
data_2014_arranged["member_casual"] = data_2014_arranged["member_casual"].replace(["Subscriber"], "member")
data_2014_arranged["member_casual"] = data_2014_arranged["member_casual"].replace(["Customer"], "casual")

# %%
data_2014_arranged.head()
# Out:
#             started_at             ended_at             start_station_name  \
# 0  2014-06-01 00:00:02  2014-06-01 00:08:42  Christopher St & Greenwich St
# 1  2014-06-01 00:00:27  2014-06-01 00:09:07       Washington Pl & Broadway
# 2  2014-06-01 00:00:32  2014-06-01 00:07:26                 E 4 St & 2 Ave
# 3  2014-06-01 00:00:34  2014-06-01 00:05:44                9 Ave & W 16 St
# 4  2014-06-01 00:00:35  2014-06-01 00:08:12                W 56 St & 6 Ave
#
#    start_station_id          end_station_name  end_station_id  start_lat  \
# 0               358     West St & Chambers St             426  40.732916
# 1               335  Stanton St & Chrystie St             265  40.729039
# 2               439        Carmine St & 6 Ave             368  40.726281
# 3               463          W 4 St & 7 Ave S             380  40.742065
# 4               352           E 58 St & 3 Ave             305  40.763406
#
#    start_lng    end_lat    end_lng member_casual
# ...

# %%
data_2013 = pd.read_csv("data_all_years/201306-citibike-tripdata.csv", encoding='UTF-8')
data_2013.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           695  2013-06-01 00:00:01  2013-06-01 00:11:36               444
# 1           693  2013-06-01 00:00:08  2013-06-01 00:11:41               444
# 2          2059  2013-06-01 00:00:44  2013-06-01 00:35:03               406
# 3           123  2013-06-01 00:01:04  2013-06-01 00:03:07               475
# 4          1521  2013-06-01 00:01:22  2013-06-01 00:26:43              2008
#
#        start station name  start station latitude  start station longitude  \
# 0      Broadway & W 24 St               40.742354               -73.989151
# 1      Broadway & W 24 St               40.742354               -73.989151
# 2  Hicks St & Montague St               40.695128               -73.995951
# 3     E 15 St & Irving Pl               40.735243               -73.987586
# 4   Little West St & 1 Pl               40.705693               -74.016777
#
# ...

# %%
data_2013_clean = data_2013[["starttime", "stoptime", "start station id", "start station name",
                           "start station latitude", "start station longitude", "end station id",
                           "end station name", "end station latitude", "end station longitude",
                           "usertype"]]

# %%
data_2013_renamed = data_2013_clean.rename(columns={"starttime": "started_at", "stoptime": "ended_at", "start station id": "start_station_id",
                               "start station name": "start_station_name", "start station latitude": "start_lat",
                               "start station longitude": "start_lng", "end station id": "end_station_id",
                               "end station name": "end_station_name", "end station latitude": "end_lat",
                               "end station longitude": "end_lng", "usertype": "member_casual"})

# %%
data_2013_arranged = data_2013_renamed[["started_at", "ended_at", "start_station_name", "start_station_id", "end_station_name",
                "end_station_id", "start_lat", "start_lng", "end_lat", "end_lng", "member_casual"]]

# %%
data_2013_arranged["member_casual"] = data_2013_arranged["member_casual"].replace(["Subscriber"], "member")
data_2013_arranged["member_casual"] = data_2013_arranged["member_casual"].replace(["Customer"], "casual")

# %%
data_2013_arranged.head()
# Out:
#             started_at             ended_at      start_station_name  \
# 0  2013-06-01 00:00:01  2013-06-01 00:11:36      Broadway & W 24 St
# 1  2013-06-01 00:00:08  2013-06-01 00:11:41      Broadway & W 24 St
# 2  2013-06-01 00:00:44  2013-06-01 00:35:03  Hicks St & Montague St
# 3  2013-06-01 00:01:04  2013-06-01 00:03:07     E 15 St & Irving Pl
# 4  2013-06-01 00:01:22  2013-06-01 00:26:43   Little West St & 1 Pl
#
#    start_station_id        end_station_name  end_station_id  start_lat  \
# 0               444         9 Ave & W 18 St           434.0  40.742354
# 1               444         9 Ave & W 18 St           434.0  40.742354
# 2               406  Hicks St & Montague St           406.0  40.695128
# 3               475         Washington Park           262.0  40.735243
# 4              2008     State St & Smith St           310.0  40.705693
#
#    start_lng    end_lat    end_lng member_casual
# 0 -73.989151  40.743174 -74.003664        member
# ...

# %%
all_years_df = pd.concat([data_2023_clean, data_2022_clean, data_2021_clean, data_2020_arranged, data_2019_arranged,
                     data_2018_arranged, data_2017_arranged, data_2016_arranged])

# %%
# all_years_df = pd.concat([decade_df, data_2013_arranged])

# %%
all_years_df.head()
# Out:
#             started_at             ended_at     start_station_name  \
# 0  2023-06-27 16:06:27  2023-06-27 16:10:27                Hilltop
# 1  2023-06-24 10:46:58  2023-06-24 10:55:27  Baldwin at Montgomery
# 2  2023-06-04 20:30:13  2023-06-04 20:34:31                Hilltop
# 3  2023-06-08 19:10:06  2023-06-08 19:13:05  Baldwin at Montgomery
# 4  2023-06-23 18:53:51  2023-06-23 19:17:50  Baldwin at Montgomery
#
#   start_station_id  end_station_name end_station_id  start_lat  start_lng  \
# 0            JC019   Christ Hospital          JC034  40.731115 -74.057468
# 1            JC020     Hamilton Park          JC009  40.723473 -74.064338
# 2            JC019      Brunswick St          JC023  40.731169 -74.057574
# 3            JC020       Astor Place          JC077  40.723499 -74.064335
# 4            JC020  Adams St & 11 St          HB507  40.723511 -74.064277
#
#      end_lat    end_lng member_casual
# 0  40.734786 -74.050444        casual
# 1  40.727596 -74.044247        member
# ...

# %%
all_years_df.isna().any()
# Out:
# started_at            False
# ended_at              False
# start_station_name     True
# start_station_id       True
# end_station_name       True
# end_station_id         True
# start_lat             False
# start_lng             False
# end_lat                True
# end_lng                True
# member_casual          True
# dtype: bool

# %%
all_years_df.dropna(inplace=True, how='any')

# %%
all_years_df.isna().any()
# Out:
# started_at            False
# ended_at              False
# start_station_name    False
# start_station_id      False
# end_station_name      False
# end_station_id        False
# start_lat             False
# start_lng             False
# end_lat               False
# end_lng               False
# member_casual         False
# dtype: bool

# %%
all_years_df.to_csv("output_datasets/yearly_data.csv", encoding='UTF-8', index=False)
